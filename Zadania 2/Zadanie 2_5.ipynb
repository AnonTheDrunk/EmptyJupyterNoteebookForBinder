# %%
n1 = input(" Chislo")
n = int(n1)
def factorial(n):
    return 1 if n ==0 else factorial(n-1)*n
print(factorial(n))
def prost(n):
    if n !=0 and n%n==0:
        return "Prostoe"
    else: return "Slojnoe"
print(prost(n))
# Out:
#  Chislo2
# 2
# Prostoe
