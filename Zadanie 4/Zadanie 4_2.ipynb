# %%
import pandas
import numpy
a = pandas.DataFrame()
a.insert(0,"Число", (range(1,11)))
a.insert(1,"Квадрат", (numpy.square(a["Число"])))
a1= pandas.DataFrame(a[a["Число"] % 2 ==0])
del a1["Число"]
print(a,a1,sep='\n')
# Out:
#    Число  Квадрат
# 0      1        1
# 1      2        4
# 2      3        9
# 3      4       16
# 4      5       25
# 5      6       36
# 6      7       49
# 7      8       64
# 8      9       81
# 9     10      100
#    Квадрат
# 1        4
# 3       16
# 5       36
# 7       64
# 9      100
