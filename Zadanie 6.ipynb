# %%
# Загрузка зависимостей
import numpy
import pandas
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pandas.read_csv('prepared_data.csv') # Убедиться в правильности пути к файлу!
dataset.head(10) # Вывод первых 10 строк
# Out:
#    Unnamed: 0      MMIN     CHMAX      MYCT      MMAX      CACH     CHMIN  \
# 0           0  0.251074  1.000000  0.489650  0.730638  1.000000  0.894427
# 1           1  0.874463  0.676123  0.131078  1.000000  0.433861  0.632456
# 2           2  0.874463  0.676123  0.131078  1.000000  0.433861  0.632456
# 3           3  0.874463  0.676123  0.131078  1.000000  0.433861  0.632456
# 4           4  0.874463  0.478091  0.131078  0.888465  0.433861  0.632456
# 5           5  0.874463  0.676123  0.104278  1.000000  0.613572  0.632456
# 6           6  1.000000  0.676123  0.074188  1.000000  0.613572  0.894427
# 7           7  1.000000  0.676123  0.074188  1.000000  0.613572  0.894427
# 8           8  1.000000  0.676123  0.074188  1.000000  0.613572  0.894427
# 9           9  1.000000  0.956183  0.074188  1.000000  0.867722  1.000000
#
#         PRP
# 0  0.759257
# 1  0.825801
# 2  0.782136
# 3  0.728689
# 4  0.671211
# 5  0.862138
# 6  0.893257
# 7  0.955579
# 8  1.000000
# 9  1.000000

# %%
# Выделение входных и выходных параметров:
# Выходной параметр - значение столбца обработанного набора данных, соответсвующее столбцу №8 из первоначального набора данных (machine.data.csv).
# Входные параметры - все остальные столбцы обработанного набора данных.
# Используем .values, чтобы индексы не попали в новые переменные и в дальнейшем не мешали нам, например, при построении графиков.
X = dataset.drop(columns=['PRP']).values
Y = dataset['PRP'].values

# Обратите внимание на структуру вашего обработанного файлы и измените индексы, если нужно.

# %%
# Разделение данных на обучающую и тестовую выборки:
# Используем метод train_test_split библиотеки sklearn.
# Он разделяет заданные массивы входных и выходных параметров на две части каждый.
# Значение test_size определяет долю тестовой выборки в исходных данных.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.

# Количество нейронов во входном слое должно быть равно количеству входных параметров.
input_layer_size = 7

# Количество нейронов в каждом скрытом слое и количество таких слоёв могут быть выбраны произвольно.
# Увеличение числа нейронов относительно предыдущего слоя позволяет лучше обрабатывать отдельные примеры.
# Уменьшение числа нейронов относительно предыдущего слоя позволяет обощать информацию и выводить новые правила.
# Увеличение числа слоёв помогает сети работать как более сложная функция.
first_hidden_layer_size = 3
second_hidden_layer_size = 3
third_hidden_layer_size = 3

# Количество нейронов в выходном слое должно быть равно количеству выходных параметров.
output_layer_size = 1

# Параметры обучения нейронной сети: количество эпох и размер батча.
epochs_number = 100
batch_size = 16

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

# Второй скрытый слой, функция активации - ReLU
model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(third_hidden_layer_size, activation='relu'))

# Выходной слой, функция активации - линейная, т.к. решается задача регрессии.
model.add(Dense(output_layer_size, activation='linear'))

# %%
# Обзор нейронной сети, теперь в ней есть слои и нейроны.
# Если внимательно посмотреть на количество параметров, т.е. связей между нейронами, то можно увидеть, что автоматически добавлены нейроны смещения.
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 3)                 24
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 52
# Trainable params: 52
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
# Функция потерь (loss) - среднеквадратическая ошибка.
# Оптимизатор (optimizer) - adam (в настоящий момент - это стандартный оптимизатор).
# Указываем метрики средняя абсолютная ошибка (mean_absolute_error) и среднеквадратическая ошиба (mean_squared_error) для дальнейшего анализа.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
# На вход передаем обучающие и тестовые выборки, количество эпох и размер батча.
# На выходе получаем объект с историей обучения, который далее будем анализировать.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 167 samples, validate on 42 samples
# Epoch 1/100
# 167/167 [==============================] - 0s 2ms/step - loss: 6.4218 - mean_absolute_error: 2.1698 - mean_squared_error: 6.4218 - val_loss: 0.6840 - val_mean_absolute_error: 0.7523 - val_mean_squared_error: 0.6840
# Epoch 2/100
# 167/167 [==============================] - 0s 337us/step - loss: 0.3534 - mean_absolute_error: 0.4961 - mean_squared_error: 0.3534 - val_loss: 0.6672 - val_mean_absolute_error: 0.6701 - val_mean_squared_error: 0.6672
# Epoch 3/100
# 167/167 [==============================] - 0s 495us/step - loss: 0.6275 - mean_absolute_error: 0.6496 - mean_squared_error: 0.6275 - val_loss: 0.1683 - val_mean_absolute_error: 0.3398 - val_mean_squared_error: 0.1683
# Epoch 4/100
# 167/167 [==============================] - 0s 519us/step - loss: 0.1526 - mean_absolute_error: 0.3137 - mean_squared_error: 0.1526 - val_loss: 0.1672 - val_mean_absolute_error: 0.3513 - val_mean_squared_error: 0.1672
# Epoch 5/100
# 167/167 [==============================] - 0s 445us/step - loss: 0.1737 - mean_absolute_error: 0.3437 - mean_squared_error: 0.1737 - val_loss: 0.1129 - val_mean_absolute_error: 0.2710 - val_mean_squared_error: 0.1129
# Epoch 6/100
# 167/167 [==============================] - 0s 200us/step - loss: 0.1250 - mean_absolute_error: 0.2810 - mean_squared_error: 0.1250 - val_loss: 0.0905 - val_mean_absolute_error: 0.2485 - val_mean_squared_error: 0.0905
# Epoch 7/100
# 167/167 [==============================] - 0s 177us/step - loss: 0.1276 - mean_absolute_error: 0.2887 - mean_squared_error: 0.1276 - val_loss: 0.0882 - val_mean_absolute_error: 0.2404 - val_mean_squared_error: 0.0882
# Epoch 8/100
# 167/167 [==============================] - 0s 165us/step - loss: 0.1193 - mean_absolute_error: 0.2755 - mean_squared_error: 0.1193 - val_loss: 0.0938 - val_mean_absolute_error: 0.2415 - val_mean_squared_error: 0.0938
# Epoch 9/100
# 167/167 [==============================] - 0s 414us/step - loss: 0.1177 - mean_absolute_error: 0.2749 - mean_squared_error: 0.1177 - val_loss: 0.0850 - val_mean_absolute_error: 0.2355 - val_mean_squared_error: 0.0850
# Epoch 10/100
# 167/167 [==============================] - 0s 170us/step - loss: 0.1157 - mean_absolute_error: 0.2729 - mean_squared_error: 0.1157 - val_loss: 0.0824 - val_mean_absolute_error: 0.2333 - val_mean_squared_error: 0.0824
# Epoch 11/100
# 167/167 [==============================] - 0s 398us/step - loss: 0.1129 - mean_absolute_error: 0.2694 - mean_squared_error: 0.1129 - val_loss: 0.0829 - val_mean_absolute_error: 0.2296 - val_mean_squared_error: 0.0829
# Epoch 12/100
# 167/167 [==============================] - 0s 160us/step - loss: 0.1104 - mean_absolute_error: 0.2654 - mean_squared_error: 0.1104 - val_loss: 0.0799 - val_mean_absolute_error: 0.2272 - val_mean_squared_error: 0.0799
# Epoch 13/100
# 167/167 [==============================] - 0s 120us/step - loss: 0.0417 - mean_absolute_error: 0.1541 - mean_squared_error: 0.0417 - val_loss: 0.0237 - val_mean_absolute_error: 0.1177 - val_mean_squared_error: 0.0237
# Epoch 93/100
# 167/167 [==============================] - 0s 157us/step - loss: 0.0420 - mean_absolute_error: 0.1532 - mean_squared_error: 0.0420 - val_loss: 0.0290 - val_mean_absolute_error: 0.1374 - val_mean_squared_error: 0.0290
# Epoch 94/100
# 167/167 [==============================] - 0s 131us/step - loss: 0.0425 - mean_absolute_error: 0.1536 - mean_squared_error: 0.0425 - val_loss: 0.0233 - val_mean_absolute_error: 0.1170 - val_mean_squared_error: 0.0233
# Epoch 95/100
# 167/167 [==============================] - 0s 357us/step - loss: 0.0408 - mean_absolute_error: 0.1511 - mean_squared_error: 0.0408 - val_loss: 0.0248 - val_mean_absolute_error: 0.1246 - val_mean_squared_error: 0.0248
# Epoch 96/100
# 167/167 [==============================] - 0s 119us/step - loss: 0.0421 - mean_absolute_error: 0.1515 - mean_squared_error: 0.0421 - val_loss: 0.0300 - val_mean_absolute_error: 0.1412 - val_mean_squared_error: 0.0300
# Epoch 97/100
# 167/167 [==============================] - 0s 126us/step - loss: 0.0418 - mean_absolute_error: 0.1519 - mean_squared_error: 0.0418 - val_loss: 0.0268 - val_mean_absolute_error: 0.1319 - val_mean_squared_error: 0.0268
# Epoch 98/100
# 167/167 [==============================] - 0s 350us/step - loss: 0.0398 - mean_absolute_error: 0.1501 - mean_squared_error: 0.0398 - val_loss: 0.0223 - val_mean_absolute_error: 0.1149 - val_mean_squared_error: 0.0223
# Epoch 99/100
# 167/167 [==============================] - 0s 134us/step - loss: 0.0396 - mean_absolute_error: 0.1481 - mean_squared_error: 0.0396 - val_loss: 0.0260 - val_mean_absolute_error: 0.1301 - val_mean_squared_error: 0.0260
# Epoch 100/100
# 167/167 [==============================] - 0s 350us/step - loss: 0.0392 - mean_absolute_error: 0.1468 - mean_squared_error: 0.0392 - val_loss: 0.0234 - val_mean_absolute_error: 0.1212 - val_mean_squared_error: 0.0234

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
# Видно, что в процессе обучения сеть с каждой эпохой вычисляет всё более точные прогнозы значений Y.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
# В идеальной ситуации они должны совпадать, т.е. точки (Y_train[i], Y_pred_train[i]) должны лежать на прямой Y_train = Y_pred_train.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([0,1], [0,1], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Таким образом, обучение по обучающей выборке проведено.
# Теперь проверим работу нейроной сети на тестовой выборке.

# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([0,1], [0,1], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Итого, качество работы нейронной сети на тестовых данных ниже, чем на обучающих - это ожидаемо.
# Тем не менее, нейронная сеть способна найти зависимости и предсказвать значение Y по X с приемлемым уровенм точности.

# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(numpy.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(numpy.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.19613824525754003
# 0.15295249327295815

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
# Для этого используем библиотеку scipy и метод stats.shapiro.
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9768549799919128, p = 0.006776775699108839
# Test k = 0.9649803638458252, p = 0.22190776467323303

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9825490713119507, p_s = 0.010870058089494705
# k_n = 3.7533280977030112, p_n = 0.15309998889519708

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
# Можо также визульно убедиться, что распределения "почти нормальное".
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
# Сохраним обученную нейронную сеть, название файла можно выбрать любое, расширение - h5.
model.save('SimpleNeuralNetwork.h5')
